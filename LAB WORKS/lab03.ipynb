# %% [markdown]
# The Tale of Numbers' Harmony
#
# In the serene village of Arithmetica, numbers were not just symbols; they were living entities that coexisted in perfect harmony. Each number had a distinct personality, contributing to the village's balance and order. But occasionally, the numbers would come together for a special event called the Harmony Gathering. During the harmony gathering, the event starts with identifying their Five Point Summary or Descriptive Statistics.
#
# For the given set of numbers who arrived for the Harmony Gathering today, can you help the people in Arithmetica find their descriptive statistics?
#
# [761, 123, 585, 275, 194, 840, 999, 622, 763, 40, 825, 687, 402, 338, 611, 987, 739, 95, 819, 568, 320, 126, 688, 948, 514, 223, 751, 379, 857, 767, 492, 162, 437, 934, 430, 343, 725, 511, 580, 678, 708, 823, 346, 179, 786, 663, 195, 890, 267, 502, 214, 300, 786, 961, 235, 559, 992, 919, 948, 318, 57, 787, 653, 317, 305, 172, 966, 182, 970, 17, 89, 624, 629, 595, 485, 752, 984, 978, 460, 124, 321, 256, 614, 852, 811, 561, 127, 207, 406, 615, 888, 391, 691, 470, 911, 401, 137, 600, 478, 682]
#
# The values that Arithmetica is looking at are:
#
# Mean
# Minimum
# Maximum
# Range
# The people of Arithmetica have another issue: they don't believe in the built-in functions (sum, len, max, min, sort, etc.) that Python provides. With the help of functions you design, try to convince the people from Arithmetica that both the outputs (the results generated by your custom functions and the functions that Python Provides) are the same.

# %%
list=[761, 123, 585, 275, 194, 840, 999, 622, 763, 40, 825, 687, 402, 338, 611, 987, 739, 95, 819, 568, 320, 126, 688, 948, 514, 223, 751, 379, 857, 767, 492, 162, 437, 934, 430, 343, 725, 511, 580, 678, 708, 823, 346, 179, 786, 663, 195, 890, 267, 502, 214, 300, 786, 961, 235, 559, 992, 919, 948, 318, 57, 787, 653, 317, 305, 172, 966, 182, 970, 17, 89, 624, 629, 595, 485, 752, 984, 978, 460, 124, 321, 256, 614, 852, 811, 561, 127, 207, 406, 615, 888, 391, 691, 470, 911, 401, 137, 600, 478, 682]

a=0
c=0
for i in list:
   a=a+i
   c=c+1 
   mean=(a/c)
print(mean)
# Out:
# 542.94

# %%
#by defining function
list1=[761, 123, 585, 275, 194, 840, 999, 622, 763, 40, 825, 687, 402, 338, 611, 987, 739, 95, 819, 568, 320, 126, 688, 948, 514, 223, 751, 379, 857, 767, 492, 162, 437, 934, 430, 343, 725, 511, 580, 678, 708, 823, 346, 179, 786, 663, 195, 890, 267, 502, 214, 300, 786, 961, 235, 559, 992, 919, 948, 318, 57, 787, 653, 317, 305, 172, 966, 182, 970, 17, 89, 624, 629, 595, 485, 752, 984, 978, 460, 124, 321, 256, 614, 852, 811, 561, 127, 207, 406, 615, 888, 391, 691, 470, 911, 401, 137, 600, 478, 682]
def mean(num):
    a=0
    c=0
    for i in list1:
        a=a+i
        c=c+1
        mean=a/c
    return mean
mean(list1)
#print(mean)
# Out:
# 542.94

# %%
max=list1[0]
for i in list1:
    if i > max:
      max=i
print("Maximum value:",max)
min=list1[0]
for i in list1:
    if i < min:
      min=i
print("Maximum value:",min)
range = max-min
print("range :",range)
# Out:
# Maximum value: 999
# Maximum value: 17
# range : 982

# %%
list=[761, 123, 585, 275, 194, 840, 999, 622, 763, 40, 825, 687, 402, 338, 611, 987, 739, 95, 819, 568, 320, 126, 688, 948, 514, 223, 751, 379, 857, 767, 492, 162, 437, 934, 430, 343, 725, 511, 580, 678, 708, 823, 346, 179, 786, 663, 195, 890, 267, 502, 214, 300, 786, 961, 235, 559, 992, 919, 948, 318, 57, 787, 653, 317, 305, 172, 966, 182, 970, 17, 89, 624, 629, 595, 485, 752, 984, 978, 460, 124, 321, 256, 614, 852, 811, 561, 127, 207, 406, 615, 888, 391, 691, 470, 911, 401, 137, 600, 478, 682]
print("Mean=",(sum(list))/(len(list)))
print("Minimum:", min(list))
print("maximum:",max(list))
range = max(list)-min(list)
print("range:",range)
# Out:
# Mean= 542.94
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\RIYA\Desktop\MScDSA-MDS171-23122028-RIYA\LAB WORKS\lab03.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> list=[761, 123, 585, 275, 194, 840, 999, 622, 763, 40, 825, 687, 402, 338, 611, 987, 739, 95, 819, 568, 320, 126, 688, 948, 514, 223, 751, 379, 857, 767, 492, 162, 437, 934, 430, 343, 725, 511, 580, 678, 708, 823, 346, 179, 786, 663, 195, 890, 267, 502, 214, 300, 786, 961, 235, 559, 992, 919, 948, 318, 57, 787, 653, 317, 305, 172, 966, 182, 970, 17, 89, 624, 629, 595, 485, 752, 984, 978, 460, 124, 321, 256, 614, 852, 811, 561, 127, 207, 406, 615, 888, 391, 691, 470, 911, 401, 137, 600, 478, 682]
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> print("Mean=",(sum(list))/(len(list)))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> print("Minimum:", min(list))
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> print("maximum:",max(list))
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> range = max(list)-min(list)
#
# TypeError: 'int' object is not callable

# %%
import statistics
mode=statistics.mode(list)
print(mode)
# Out:
# 948

# %%
import statistics
median=statistics.median(list)
print(median)
# Out:
# 574.0

# %%
def mode(list):
    mode1 = mode(list)
    count=0
    for item in list:
        if item in mode1:
            count=count+1
        else:
            print("next")
mode(list)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# c:\Users\RIYA\Desktop\MScDSA-MDS171-23122028-RIYA\LAB WORKS\lab03.ipynb Cell 8 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>         else:
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>             print("next")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> mode(list)
#
# c:\Users\RIYA\Desktop\MScDSA-MDS171-23122028-RIYA\LAB WORKS\lab03.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> def mode(list):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>     mode1 = mode(list)
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     count=0
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     for item in list:
#
# c:\Users\RIYA\Desktop\MScDSA-MDS171-23122028-RIYA\LAB WORKS\lab03.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> def mode(list):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>     mode1 = mode(list)
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     count=0
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     for item in list:
#
#     [... skipping similar frames: mode at line 2 (2971 times)]
#
# c:\Users\RIYA\Desktop\MScDSA-MDS171-23122028-RIYA\LAB WORKS\lab03.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> def mode(list):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>     mode1 = mode(list)
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     count=0
#       <a href='vscode-notebook-cell:/c%3A/Users/RIYA/Desktop/MScDSA-MDS171-23122028-RIYA/LAB%20WORKS/lab03.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a>     for item in list:
#
# RecursionError: maximum recursion depth exceeded
