# %%
#develop a contact managment program where isers can add,edit,delete and search 
# new contact details using a dictionary.the menue options would facilitate these actions.

# %%
# class information:
#     def __init__(self):
#         self.contact={}


#     def addDetails(self):
#             n =int(input("enter the number of values to be added"))
#             for i in range(n):
#                 global name
#                 name=input("enter the name of the costumer")
#                 phno=input("enter the phone number")
#                 age=input("enter the age")

#                 self.new={
#                     name:{
#                         "name":name,
#                         "phone num":phno,
#                         "age":age
#                     }
#                 }
#                 self.contact.update(self.new)
#             print(self.contact)

#     def editDetails(self):
#         enter=input("enter the detail to be changed")
#         if enter == "name":
#               name = input("Enter the name in which name is to be changed: ")
#               newname=input("enter the new name")
#               self.contact[name]["name"]=newname
#               print("Edited array : ",self.contact)
#         elif enter=="phone num":
#               name=input("enter the name in which  phonenumber to be edited")
#               newph=int(input("enter the new phone number"))
#               self.contact[name]["phone num"]=newph
#               print("edited array",self.contact)
#         elif enter =="age":
#              name=input("enter the name in which age is to be changed")
#              newage=int(input("enter the new age"))
#              self.contact[name]["age"]=newage
#              print("edited array:",self.contact)
#         else:
#              print("invalid input")
        

#     def delData(self):
#         delete=input("enter the info to be deleted")
#         for delete in self.contact.keys():
#              self.contact.pop(delete)

#     def searchData(self):
#         search=input("enter the name to be searched")
#         for sce in self.contact():
#             flag=True
#             if sce==search:
#                    print(self.contact[search])
#             else:
#                  flag=False
#         if(flag==False):
#              print("Name not available")
            
# obj=information()
# obj.addDetails()
# obj.editDetails()

# %%
print("menue")
print("1.add")
print("2.edit")
print("3.delete")
print("4.search")

while True:
     choice=input("enter ypur choice")


     if choice=="1":
          obj.addDetails()
     elif choice=="2":
          obj.editDetails()
     elif choice=="3":
          obj.delData()
     elif choice=="4":
          obj.searchData()
     else:
          print("invalid")
# Out:
# menue
# 1.add
# 2.edit
# 3.delete
# 4.search
# {'riya': {'name': 'riya', 'phone num': '8590791082', 'age': '22'}}
# {'riya': {'name': 'riya', 'phone num': '8590791082', 'age': '22'}, 'sukku': {'name': 'sukku', 'phone num': '1234567890', 'age': '19'}}
# Edited array :  {'riya': {'name': 'riya', 'phone num': '8590791082', 'age': '22'}, 'sukku': {'name': 'ardra', 'phone num': '1234567890', 'age': '19'}}
# invalid input
# Edited array :  {'riya': {'name': '5', 'phone num': '8590791082', 'age': '22'}, 'sukku': {'name': 'ardra', 'phone num': '1234567890', 'age': '19'}}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\CHRIST\sem 1\Python\xam.py\2.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/d%3A/CHRIST/sem%201/Python/xam.py/2.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a>      obj.editDetails()
# ...

# %%
# name=input("enter the name of the costumer")
# phno=input("enter the phone number")
# age=input("enter the age")


class information:
    def __init__(self):
        self.contact={}


    def addDetails(self,name,phno,age):
            

               self.new={
                    name:{
                        "name":name,
                        "phone num":phno,
                        "age":age
                    }
                }
               self.contact.update(self.new)
               print(self.contact)

    def editDetails(self):
        enter=input("enter the detail to be changed")
        if enter == "name":
              name = input("Enter the name in which name is to be changed: ")
              newname=input("enter the new name")
              self.contact[name]["name"]=newname
              print("Edited array : ",self.contact)
        elif enter=="phone num":
              name=input("enter the name in which  phonenumber to be edited")
              newph=int(input("enter the new phone number"))
              self.contact[name]["phone num"]=newph
              print("edited array",self.contact)
        elif enter =="age":
             name=input("enter the name in which age is to be changed")
             newage=int(input("enter the new age"))
             self.contact[name]["age"]=newage
             print("edited array:",self.contact)
        else:
             print("invalid input")
        

    def delData(self):
        delete=input("enter the info to be deleted")
        
        self.contact.pop(delete)
        print(self.contact)
     
    def searchData(self):
        search=input("enter the name to be searched")
        for sce in self.contact.keys():
            flag=True
            if sce==search:
                   print(self.contact[search])
            else:
                 flag=False
        if(flag==False):
             print("Name not available")

#     def searchData(self):
#          search=input("enter the name to be searched")
#          for sce in self.contact.keys():
#               if sce==search:
#                    print(self.contact[search])
obj=information()



print("menue")
print("1.add")
print("2.edit")
print("3.delete")
print("4.search")

while True:
     choice=input("enter your choice")


     if choice=="1":
          n =int(input("enter the number of values to be added"))
          for i in range(n):
              
               name=input("enter the name of the costumer")
               phno=input("enter the phone number")
               age=input("enter the age")
          obj.addDetails(name,phno,age)
          

     elif choice=="2":
               obj.editDetails()
     elif choice=="3":
               obj.delData()
     elif choice=="4":
               obj.searchData()
     else:
        print("invalid")
# Out:
# menue
# 1.add
# 2.edit
# 3.delete
# 4.search
# {'riya': {'name': 'riya', 'phone num': '45', 'age': '2'}}
# {'name': 'riya', 'phone num': '45', 'age': '2'}
# invalid input
# invalid
# invalid
# invalid
# invalid
# invalid
# invalid
