# %% [markdown]
# create a class pandas_name that will help you to read csv file and print the top/bottom n rows in the file

# %%
class pandas_Riya: 
    def __init__(self):
        self.filename=" "
        self.filecontent=" "    

    def read_csv(self,filename):
        self.filename=filename
        try:
            with open(filename ,"r+") as file:
                self.filecontent=file.readlines()
        except:
            print("file not found")
    def head(self,num_of_rows):
        for i in range(0,num_of_rows):
            print(self.filecontent[i].strip())

    def tail(self,num_of_rows):
        start=len(self.filecontent)-(num_of_rows +1)
        end=len(self.filecontent)-1
        for i in range(start,end):
            print(self.filecontent[i].strip())
pd=pandas_Riya()#obj
pd.read_csv("sample.txt")
pd.head(2)
pd.tail(2)
# Out:
# this is my first line
# this is my first line
# this is my first line

# %%
import pandas as pd
df=pd.read_csv("sample.txt")
print(df.head(2))
print(df.tail(2))
print(df.columns)
# Out:
#     this is my first line
# 0   this is my first line
# 1   this is my first line
#     this is my first line
# 1   this is my first line
# 2   this is my first line
# Index([' this is my first line'], dtype='object')

# %% [markdown]
# write a python program that will read a csv file and print the mean median and mode for colum of user choice

# %%
# x=[]
# def readCsv():
    
#     with open("data.csv","r") as file:
#         z=file.readlines()
#     for i in z:
#         splitz=i.strip().split(",")
#         # print(splitz)
#         for j in splitz:
#             print(j,end="\t")
#         print("")
#     x.append(splitz)
#     print(x)
#     #for element in splitz:
        
#         #x.append(splitz)
#     #print(x)

#         #print(splitz)
    
#         # print()
#         #x.append(i)
#     # df=pd.DataFrame(z)
#     # df

# readCsv()
# Out:
# gender	NationalITy	PlaceofBirth	StageID	GradeID	SectionID	Topic	Semester	Relation	raisedhands	VisITedResources	AnnouncementsView	Discussion	ParentAnsweringSurvey	ParentschoolSatisfaction	StudentAbsenceDays	Class
# M	KW	KuwaIT	lowerlevel	G-04	A	IT	F	Father	15	16	2	20	Yes	Good	Under-7	M
# M	KW	KuwaIT	lowerlevel	G-04	A	IT	F	Father	20	20	3	25	Yes	Good	Under-7	M
# M	KW	KuwaIT	lowerlevel	G-04	A	IT	F	Father	10	7	0	30	No	Bad	Above-7	L
# M	KW	KuwaIT	lowerlevel	G-04	A	IT	F	Father	30	25	5	35	No	Bad	Above-7	L
# M	KW	KuwaIT	lowerlevel	G-04	A	IT	F	Father	40	50	12	50	No	Bad	Above-7	M
# F	KW	KuwaIT	lowerlevel	G-04	A	IT	F	Father	42	30	13	70	Yes	Bad	Above-7	M
# M	KW	KuwaIT	MiddleSchool	G-07	A	Math	F	Father	35	12	0	17	No	Bad	Above-7	L
# M	KW	KuwaIT	MiddleSchool	G-07	A	Math	F	Father	50	10	15	22	Yes	Good	Under-7	M
# F	KW	KuwaIT	MiddleSchool	G-07	A	Math	F	Father	12	21	16	50	Yes	Good	Under-7	M
# F	KW	KuwaIT	MiddleSchool	G-07	B	IT	F	Father	70	80	25	70	Yes	Good	Under-7	M
# ...

# %%
# values=[]
# def getUserinput():
    
#     t=int(input("enter the column"))
#     for i in x:
       
#             values=values.append(i)
#     print(values)

    
# getUserinput()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# d:\CHRIST\sem 1\Python\pandas.ipynb\pandas1.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/d%3A/CHRIST/sem%201/Python/pandas.ipynb/pandas1.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a>             values=values.append(i)
#       <a href='vscode-notebook-cell:/d%3A/CHRIST/sem%201/Python/pandas.ipynb/pandas1.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>     print(values)
# ---> <a href='vscode-notebook-cell:/d%3A/CHRIST/sem%201/Python/pandas.ipynb/pandas1.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> getUserinput()
#
# d:\CHRIST\sem 1\Python\pandas.ipynb\pandas1.ipynb Cell 6 line 7
#       <a href='vscode-notebook-cell:/d%3A/CHRIST/sem%201/Python/pandas.ipynb/pandas1.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> t=int(input("enter the column"))
# ...

# %%
# sum=0
# def meanValue():
#     for i in :

# %%
with open("data.csv","r") as file:
    lis=[]
    n=int(input("enter the colunm number"))
    
    for i in file:
        z = file.readline()
        line=z.strip().split(",")
        lis.append(line)
print(lis)
# Out:
# [['M', 'KW', 'KuwaIT', 'lowerlevel', 'G-04', 'A', 'IT', 'F', 'Father', '15', '16', '2', '20', 'Yes', 'Good', 'Under-7', 'M'], ['M', 'KW', 'KuwaIT', 'lowerlevel', 'G-04', 'A', 'IT', 'F', 'Father', '10', '7', '0', '30', 'No', 'Bad', 'Above-7', 'L'], ['M', 'KW', 'KuwaIT', 'lowerlevel', 'G-04', 'A', 'IT', 'F', 'Father', '40', '50', '12', '50', 'No', 'Bad', 'Above-7', 'M'], ['M', 'KW', 'KuwaIT', 'MiddleSchool', 'G-07', 'A', 'Math', 'F', 'Father', '35', '12', '0', '17', 'No', 'Bad', 'Above-7', 'L'], ['F', 'KW', 'KuwaIT', 'MiddleSchool', 'G-07', 'A', 'Math', 'F', 'Father', '12', '21', '16', '50', 'Yes', 'Good', 'Under-7', 'M'], ['M', 'KW', 'KuwaIT', 'MiddleSchool', 'G-07', 'A', 'Math', 'F', 'Father', '50', '88', '30', '80', 'Yes', 'Good', 'Under-7', 'H'], ['M', 'KW', 'KuwaIT', 'lowerlevel', 'G-04', 'A', 'IT', 'F', 'Father', '5', '1', '0', '11', 'No', 'Bad', 'Above-7', 'L'], ['F', 'KW', 'KuwaIT', 'MiddleSchool', 'G-08', 'A', 'Math', 'F', 'Mum', '62', '70', '44', '60', 'No', 'Bad', 'Above-7',
# ...
